# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
train = pd.read_csv("data/training.csv")
train.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
train.columns
# Out:
# Index([u'EventId', u'DER_mass_MMC', u'DER_mass_transverse_met_lep',
#        u'DER_mass_vis', u'DER_pt_h', u'DER_deltaeta_jet_jet',
#        u'DER_mass_jet_jet', u'DER_prodeta_jet_jet', u'DER_deltar_tau_lep',
#        u'DER_pt_tot', u'DER_sum_pt', u'DER_pt_ratio_lep_tau',
#        u'DER_met_phi_centrality', u'DER_lep_eta_centrality', u'PRI_tau_pt',
#        u'PRI_tau_eta', u'PRI_tau_phi', u'PRI_lep_pt', u'PRI_lep_eta',
#        u'PRI_lep_phi', u'PRI_met', u'PRI_met_phi', u'PRI_met_sumet',
#        u'PRI_jet_num', u'PRI_jet_leading_pt', u'PRI_jet_leading_eta',
#        u'PRI_jet_leading_phi', u'PRI_jet_subleading_pt',
#        u'PRI_jet_subleading_eta', u'PRI_jet_subleading_phi', u'PRI_jet_all_pt',
#        u'Weight', u'Label'],
#       dtype='object')

# %%
# check if any nan values
train.isnull().sum()
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# ...

# %%
# drop event ids
train_df = train.drop('EventId',axis=1)
train_df.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               3.064      41.928     197.760                 1.582
# ...

# %%
features_corr = train_df.corr()

# %%
features_corr.DER_deltaeta_jet_jet
# Out:
# DER_mass_MMC                   0.162661
# DER_mass_transverse_met_lep   -0.176386
# DER_mass_vis                  -0.032251
# DER_pt_h                       0.523664
# DER_deltaeta_jet_jet           1.000000
# DER_mass_jet_jet               0.946045
# DER_prodeta_jet_jet            0.999981
# DER_deltar_tau_lep            -0.299076
# DER_pt_tot                     0.270878
# DER_sum_pt                     0.671996
# DER_pt_ratio_lep_tau           0.041307
# DER_met_phi_centrality         0.368492
# DER_lep_eta_centrality         0.999998
# PRI_tau_pt                     0.188086
# PRI_tau_eta                    0.004866
# PRI_tau_phi                    0.003302
# PRI_lep_pt                     0.168039
# PRI_lep_eta                    0.008678
# PRI_lep_phi                    0.000069
# PRI_met                        0.305561
# PRI_met_phi                    0.005245
# PRI_met_sumet                  0.619100
# PRI_jet_num                    0.867521
# ...

# %%
columns_with_90_corr_DER_deltaeta_jet_jet = features_corr.DER_deltaeta_jet_jet.index[(features_corr.DER_deltaeta_jet_jet.values > 0.90) & 
                                                                                     (features_corr.DER_deltaeta_jet_jet.values < 1.00)]
columns_with_90_corr_DER_deltaeta_jet_jet
# Out:
# Index([u'DER_mass_jet_jet', u'DER_prodeta_jet_jet', u'DER_lep_eta_centrality',
#        u'PRI_jet_subleading_pt', u'PRI_jet_subleading_eta',
#        u'PRI_jet_subleading_phi'],
#       dtype='object')

# %%
train_df = train_df.drop(columns_with_90_corr_DER_deltaeta_jet_jet, axis=1)
train_df.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  \
# 0                  0.91               3.064      41.928     197.760
# 1               -999.00               3.473       2.078     125.157
# 2               -999.00               3.148       9.336     197.814
# 3               -999.00               3.310       0.414      75.968
# 4               -999.00               3.891      16.405      57.983
#
#    DER_pt_ratio_lep_tau  DER_met_phi_centrality  PRI_tau_pt  PRI_tau_eta  \
# ...

# %%
len(train_df.columns)
# Out:
# 26

# %%
features_corr = train_df.corr()
features_corr.DER_mass_MMC
# Out:
# DER_mass_MMC                   1.000000
# DER_mass_transverse_met_lep   -0.455755
# DER_mass_vis                   0.168548
# DER_pt_h                       0.198765
# DER_deltaeta_jet_jet           0.162661
# DER_deltar_tau_lep             0.228105
# DER_pt_tot                     0.045826
# DER_sum_pt                     0.201464
# DER_pt_ratio_lep_tau          -0.017073
# DER_met_phi_centrality         0.358963
# PRI_tau_pt                     0.131495
# PRI_tau_eta                    0.002579
# PRI_tau_phi                   -0.006177
# PRI_lep_pt                     0.099445
# PRI_lep_eta                    0.010060
# PRI_lep_phi                   -0.000744
# PRI_met                       -0.233724
# PRI_met_phi                    0.007411
# PRI_met_sumet                  0.221984
# PRI_jet_num                    0.221078
# PRI_jet_leading_pt             0.250158
# PRI_jet_leading_eta            0.247083
# PRI_jet_leading_phi            0.247078
# ...

# %%
features_corr.DER_pt_h
# Out:
# DER_mass_MMC                   0.198765
# DER_mass_transverse_met_lep   -0.249116
# DER_mass_vis                  -0.062562
# DER_pt_h                       1.000000
# DER_deltaeta_jet_jet           0.523664
# DER_deltar_tau_lep            -0.539379
# DER_pt_tot                     0.310501
# DER_sum_pt                     0.832733
# DER_pt_ratio_lep_tau           0.089187
# DER_met_phi_centrality         0.539356
# PRI_tau_pt                     0.407421
# PRI_tau_eta                    0.001665
# PRI_tau_phi                    0.005248
# PRI_lep_pt                     0.360939
# PRI_lep_eta                    0.008354
# PRI_lep_phi                   -0.002923
# PRI_met                        0.679585
# PRI_met_phi                    0.008585
# PRI_met_sumet                  0.782547
# PRI_jet_num                    0.623401
# PRI_jet_leading_pt             0.621599
# PRI_jet_leading_eta            0.564898
# PRI_jet_leading_phi            0.564894
# ...

# %%
features_corr
# Out:
#                              DER_mass_MMC  DER_mass_transverse_met_lep  \
# DER_mass_MMC                     1.000000                    -0.455755
# DER_mass_transverse_met_lep     -0.455755                     1.000000
# DER_mass_vis                     0.168548                     0.190109
# DER_pt_h                         0.198765                    -0.249116
# DER_deltaeta_jet_jet             0.162661                    -0.176386
# DER_deltar_tau_lep               0.228105                     0.043251
# DER_pt_tot                       0.045826                     0.017758
# DER_sum_pt                       0.201464                    -0.146837
# DER_pt_ratio_lep_tau            -0.017073                     0.349504
# DER_met_phi_centrality           0.358963                    -0.419757
# PRI_tau_pt                       0.131495                    -0.145464
# PRI_tau_eta                      0.002579                    -0.002109
# ...

# %%
features_corr.PRI_jet_leading_pt
# Out:
# DER_mass_MMC                   0.250158
# DER_mass_transverse_met_lep   -0.229674
# DER_mass_vis                  -0.019151
# DER_pt_h                       0.621599
# DER_deltaeta_jet_jet           0.545027
# DER_deltar_tau_lep            -0.335851
# DER_pt_tot                     0.202920
# DER_sum_pt                     0.638796
# DER_pt_ratio_lep_tau           0.049090
# DER_met_phi_centrality         0.548613
# PRI_tau_pt                     0.199011
# PRI_tau_eta                    0.009043
# PRI_tau_phi                    0.003696
# PRI_lep_pt                     0.183276
# PRI_lep_eta                    0.020687
# PRI_lep_phi                    0.000214
# PRI_met                        0.299557
# PRI_met_phi                    0.006805
# PRI_met_sumet                  0.595121
# PRI_jet_num                    0.832493
# PRI_jet_leading_pt             1.000000
# PRI_jet_leading_eta            0.996100
# PRI_jet_leading_phi            0.996100
# ...

# %%
features_corr.PRI_jet_leading_eta
# Out:
# DER_mass_MMC                   0.247083
# DER_mass_transverse_met_lep   -0.220370
# DER_mass_vis                  -0.013749
# DER_pt_h                       0.564898
# DER_deltaeta_jet_jet           0.521657
# DER_deltar_tau_lep            -0.304161
# DER_pt_tot                     0.186564
# DER_sum_pt                     0.578616
# DER_pt_ratio_lep_tau           0.043323
# DER_met_phi_centrality         0.534409
# PRI_tau_pt                     0.170910
# PRI_tau_eta                    0.009792
# PRI_tau_phi                    0.003367
# PRI_lep_pt                     0.158860
# PRI_lep_eta                    0.021661
# PRI_lep_phi                    0.000544
# PRI_met                        0.252509
# PRI_met_phi                    0.006455
# PRI_met_sumet                  0.541377
# PRI_jet_num                    0.817360
# PRI_jet_leading_pt             0.996100
# PRI_jet_leading_eta            1.000000
# PRI_jet_leading_phi            0.999992
# ...

# %%
train_df = train_df.drop(["PRI_jet_leading_eta","PRI_jet_leading_phi"],axis=1)

# %%
features_corr = train_df.corr()
features_corr
# Out:
#                              DER_mass_MMC  DER_mass_transverse_met_lep  \
# DER_mass_MMC                     1.000000                    -0.455755
# DER_mass_transverse_met_lep     -0.455755                     1.000000
# DER_mass_vis                     0.168548                     0.190109
# DER_pt_h                         0.198765                    -0.249116
# DER_deltaeta_jet_jet             0.162661                    -0.176386
# DER_deltar_tau_lep               0.228105                     0.043251
# DER_pt_tot                       0.045826                     0.017758
# DER_sum_pt                       0.201464                    -0.146837
# DER_pt_ratio_lep_tau            -0.017073                     0.349504
# DER_met_phi_centrality           0.358963                    -0.419757
# PRI_tau_pt                       0.131495                    -0.145464
# PRI_tau_eta                      0.002579                    -0.002109
# ...

# %%
train_df = train_df.drop("PRI_jet_all_pt",axis=1)

# %%
cols_to_drop = list(columns_with_90_corr_DER_deltaeta_jet_jet.values) + ["PRI_jet_all_pt", "PRI_jet_leading_eta","PRI_jet_leading_phi"]
cols_to_drop
# Out:
# ['DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_lep_eta_centrality',
#  'PRI_jet_subleading_pt',
#  'PRI_jet_subleading_eta',
#  'PRI_jet_subleading_phi',
#  'PRI_jet_all_pt',
#  'PRI_jet_leading_eta',
#  'PRI_jet_leading_phi']

# %%
with open("features_to_drop.txt","w") as f:
    for col in cols_to_drop:
        f.write(col + "\n")
