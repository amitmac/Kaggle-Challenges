# %%
import tensorflow as tf
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
features_to_drop = []
with open("features_to_drop.txt","r")as f:
    for line in f.readlines():
        features_to_drop.append(line.strip("\n"))
features_to_drop
# Out:
# ['DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_lep_eta_centrality',
#  'PRI_jet_subleading_pt',
#  'PRI_jet_subleading_eta',
#  'PRI_jet_subleading_phi',
#  'PRI_jet_all_pt',
#  'PRI_jet_leading_eta',
#  'PRI_jet_leading_phi']

# %%
train = pd.read_csv("data/training.csv")
train.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               3.064      41.928     197.760                 1.582
# 1               3.473       2.078     125.157                 0.879
# 2               3.148       9.336     197.814                 3.776
# 3               3.310       0.414      75.968                 2.354
# 4               3.891      16.405      57.983                 1.056
#
#    DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  PRI_tau_eta  \
# 0                   1.396                     0.2      32.638        1.017
# 1                   1.414                  -999.0      42.014        2.039
# 2                   1.414                  -999.0      32.154       -0.705
# 3                  -1.285                  -999.0      22.647       -1.655
# 4                  -1.385                  -999.0      28.209       -2.197
#
#    PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_met  PRI_met_phi  \
# 0        0.381      51.626        2.273       -2.414   16.824       -0.277
# 1       -3.011      36.918        0.501        0.103   44.704       -1.916
# 2       -2.093     121.409       -0.953        1.052   54.283       -2.186
# 3        0.010      53.321       -0.522       -3.100   31.082        0.060
# 4       -2.231      29.774        0.798        1.569    2.723       -0.871
#
#    PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0        258.733            2              67.435                2.150
# 1        164.546            1              46.226                0.725
# 2        260.414            1              44.251                2.053
# 3         86.062            0            -999.000             -999.000
# 4         53.131            0            -999.000             -999.000
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                0.444                 46.062                    1.24
# 1                1.158               -999.000                 -999.00
# 2               -2.028               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt    Weight Label
# 0                  -2.475         113.497  0.002653     s
# 1                -999.000          46.226  2.233584     b
# 2                -999.000          44.251  2.347389     b
# 3                -999.000          -0.000  5.446378     b
# 4                -999.000           0.000  6.245333     b

# %%
X_train = train.iloc[:,1:-2]
y_train = train.iloc[:,-1]

X_train.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               3.064      41.928     197.760                 1.582
# 1               3.473       2.078     125.157                 0.879
# 2               3.148       9.336     197.814                 3.776
# 3               3.310       0.414      75.968                 2.354
# 4               3.891      16.405      57.983                 1.056
#
#    DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  PRI_tau_eta  \
# 0                   1.396                     0.2      32.638        1.017
# 1                   1.414                  -999.0      42.014        2.039
# 2                   1.414                  -999.0      32.154       -0.705
# 3                  -1.285                  -999.0      22.647       -1.655
# 4                  -1.385                  -999.0      28.209       -2.197
#
#    PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_met  PRI_met_phi  \
# 0        0.381      51.626        2.273       -2.414   16.824       -0.277
# 1       -3.011      36.918        0.501        0.103   44.704       -1.916
# 2       -2.093     121.409       -0.953        1.052   54.283       -2.186
# 3        0.010      53.321       -0.522       -3.100   31.082        0.060
# 4       -2.231      29.774        0.798        1.569    2.723       -0.871
#
#    PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0        258.733            2              67.435                2.150
# 1        164.546            1              46.226                0.725
# 2        260.414            1              44.251                2.053
# 3         86.062            0            -999.000             -999.000
# 4         53.131            0            -999.000             -999.000
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                0.444                 46.062                    1.24
# 1                1.158               -999.000                 -999.00
# 2               -2.028               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt
# 0                  -2.475         113.497
# 1                -999.000          46.226
# 2                -999.000          44.251
# 3                -999.000          -0.000
# 4                -999.000           0.000

# %%
X_train = X_train.drop(features_to_drop, axis=1)
X_train.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  \
# 0                  0.91               3.064      41.928     197.760
# 1               -999.00               3.473       2.078     125.157
# 2               -999.00               3.148       9.336     197.814
# 3               -999.00               3.310       0.414      75.968
# 4               -999.00               3.891      16.405      57.983
#
#    DER_pt_ratio_lep_tau  DER_met_phi_centrality  PRI_tau_pt  PRI_tau_eta  \
# 0                 1.582                   1.396      32.638        1.017
# 1                 0.879                   1.414      42.014        2.039
# 2                 3.776                   1.414      32.154       -0.705
# 3                 2.354                  -1.285      22.647       -1.655
# 4                 1.056                  -1.385      28.209       -2.197
#
#    PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_met  PRI_met_phi  \
# 0        0.381      51.626        2.273       -2.414   16.824       -0.277
# 1       -3.011      36.918        0.501        0.103   44.704       -1.916
# 2       -2.093     121.409       -0.953        1.052   54.283       -2.186
# 3        0.010      53.321       -0.522       -3.100   31.082        0.060
# 4       -2.231      29.774        0.798        1.569    2.723       -0.871
#
#    PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt
# 0        258.733            2              67.435
# 1        164.546            1              46.226
# 2        260.414            1              44.251
# 3         86.062            0            -999.000
# 4         53.131            0            -999.000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.8, random_state=42)

# %%
num_features = len(X_train.columns)
num_class = 2
num_hidden_units = 50
keep_prob = tf.placeholder(tf.float32)

# %%
X = tf.placeholder(shape=[None, num_features], dtype=tf.float32, name="x_input")
y = tf.placeholder(shape=[None, num_class], dtype=tf.int32, name="y_input")

# %%
# Create 1st hidden layer
W_1 = tf.Variable(tf.random_normal([num_features, num_hidden_units], mean=0, stddev=1))
b_1 = tf.Variable(tf.zeros([num_hidden_units]))

# Create 2nd hidden layer
W_2 = tf.Variable(tf.random_normal([num_hidden_units, num_class], mean=0, stddev=1))
b_2 = tf.Variable(tf.zeros([num_class]))

# %%
logits_1 = tf.add(tf.matmul(X, W_1), b_1)
logits_1_dropout = tf.nn.dropout(logits_1, keep_prob)
act_1 = tf.nn.relu(logits_1_dropout)

logits_2 = tf.add(tf.matmul(act_1, W_2), b_2)
output_logits = tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=logits_2)

output_pred = tf.nn.softmax(logits_2)

loss = tf.reduce_mean(output_logits)

# %%
train_step = tf.train.AdamOptimizer().minimize(loss)

# %%
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(output_pred, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
y_t = np.zeros([len(y_train), 2], dtype=np.int32)
y_t[(range(len(y_train)), y_train)] = 1

# %%
y_v = np.zeros([len(y_valid), 2], dtype=np.int32)
y_v[(range(len(y_valid)), y_valid)] = 1

# %%
loss_track = []
num_epochs = 20000
batch_size = 150
total_batches = len(X_train)/batch_size
for i in range(20000):
    for j in range(total_batches):
        X_batch = X_train[j*batch_size:(j+1)*batch_size]
        y_batch = y_t[j*batch_size:(j+1)*batch_size]
            
        _, l = sess.run([train_step, loss],{X:X_batch, y:y_batch, keep_prob:0.5})
        loss_track.append(l)
        
    if i%100==0:
        train_accuracy = sess.run(accuracy,{X:X_batch, y:y_batch, keep_prob:1.0})
        valid_accuracy = sess.run(accuracy,{X:X_valid, y:y_v, keep_prob:1.0})

        print "Epoch",i
        print("Train Accuracy: %f, Valid Accuracy: %f, Loss: %f"%(train_accuracy, valid_accuracy, l))
# Out:
# Epoch 0
# Train Accuracy: 0.660000, Valid Accuracy: 0.678405, Loss: 23.972950
# Epoch 100
# Train Accuracy: 0.713333, Valid Accuracy: 0.751385, Loss: 0.583878
# Epoch 200
# Train Accuracy: 0.726667, Valid Accuracy: 0.777735, Loss: 0.538065
# Epoch 300
# Train Accuracy: 0.766667, Valid Accuracy: 0.798275, Loss: 0.491417
# Epoch 400
# Train Accuracy: 0.753333, Valid Accuracy: 0.802520, Loss: 0.516448
# Epoch 500
# Train Accuracy: 0.766667, Valid Accuracy: 0.799135, Loss: 0.576875
# Epoch 600
# Train Accuracy: 0.753333, Valid Accuracy: 0.802380, Loss: 0.550674
# Epoch 700
# Train Accuracy: 0.760000, Valid Accuracy: 0.803470, Loss: 0.518208
# Epoch 800
# Train Accuracy: 0.780000, Valid Accuracy: 0.805445, Loss: 0.541005
# Epoch 900
# Train Accuracy: 0.766667, Valid Accuracy: 0.807060, Loss: 0.532248
# Epoch 1000
# Train Accuracy: 0.766667, Valid Accuracy: 0.805305, Loss: 0.557178
# Epoch 1100
# Train Accuracy: 0.766667, Valid Accuracy: 0.807080, Loss: 0.501637
# Epoch 1200
# Train Accuracy: 0.766667, Valid Accuracy: 0.805800, Loss: 0.528035
# Epoch 1300
# Train Accuracy: 0.760000, Valid Accuracy: 0.806570, Loss: 0.510992
# Epoch 1400
# Train Accuracy: 0.760000, Valid Accuracy: 0.807130, Loss: 0.514697
# Epoch 1500
# Train Accuracy: 0.773333, Valid Accuracy: 0.808390, Loss: 0.523812
# Epoch 1600
# Train Accuracy: 0.766667, Valid Accuracy: 0.810630, Loss: 0.579312
# Epoch 1700
# Train Accuracy: 0.753333, Valid Accuracy: 0.807855, Loss: 0.518219
# Epoch 1800
# Train Accuracy: 0.766667, Valid Accuracy: 0.808675, Loss: 0.491659
# Epoch 1900
# Train Accuracy: 0.773333, Valid Accuracy: 0.808850, Loss: 0.517208
# Epoch 2000
# Train Accuracy: 0.726667, Valid Accuracy: 0.809135, Loss: 0.553286
# Epoch 2100
# Train Accuracy: 0.760000, Valid Accuracy: 0.808700, Loss: 0.577861
# Epoch 5200
# Train Accuracy: 0.773333, Valid Accuracy: 0.815775, Loss: 0.508564
# Epoch 5300
# Train Accuracy: 0.786667, Valid Accuracy: 0.814360, Loss: 0.505184
# Epoch 5400
# Train Accuracy: 0.793333, Valid Accuracy: 0.812550, Loss: 0.555769
# Epoch 5500
# Train Accuracy: 0.786667, Valid Accuracy: 0.812685, Loss: 0.524937
# Epoch 5600
# Train Accuracy: 0.786667, Valid Accuracy: 0.812250, Loss: 0.535525
# Epoch 5700
# Train Accuracy: 0.786667, Valid Accuracy: 0.812835, Loss: 0.525232
# Epoch 5800
# Train Accuracy: 0.780000, Valid Accuracy: 0.814945, Loss: 0.484935
# Epoch 5900
# Train Accuracy: 0.793333, Valid Accuracy: 0.814185, Loss: 0.604626
# Epoch 6000
# Train Accuracy: 0.793333, Valid Accuracy: 0.814550, Loss: 0.513344
# Epoch 6100
# Train Accuracy: 0.800000, Valid Accuracy: 0.812880, Loss: 0.595720
# Epoch 6200
# Train Accuracy: 0.773333, Valid Accuracy: 0.813135, Loss: 0.514959
# Epoch 6300
# Train Accuracy: 0.773333, Valid Accuracy: 0.814855, Loss: 0.526087
# Epoch 6400
# Train Accuracy: 0.793333, Valid Accuracy: 0.815485, Loss: 0.515419
# Epoch 6500
# Train Accuracy: 0.800000, Valid Accuracy: 0.811360, Loss: 0.490459
# Epoch 6600
# Train Accuracy: 0.793333, Valid Accuracy: 0.811905, Loss: 0.560998
# Epoch 6700
# Train Accuracy: 0.766667, Valid Accuracy: 0.814335, Loss: 0.570609
# Epoch 6800
# Train Accuracy: 0.793333, Valid Accuracy: 0.812015, Loss: 0.528331
# Epoch 6900
# Train Accuracy: 0.793333, Valid Accuracy: 0.813540, Loss: 0.528706
# Epoch 7000
# Train Accuracy: 0.780000, Valid Accuracy: 0.814070, Loss: 0.539734
# Epoch 7100
# Train Accuracy: 0.773333, Valid Accuracy: 0.810880, Loss: 0.546333
# Epoch 7200
# Train Accuracy: 0.786667, Valid Accuracy: 0.814035, Loss: 0.480922
# Epoch 7300
# Train Accuracy: 0.780000, Valid Accuracy: 0.812665, Loss: 0.608822
# Epoch 7400
# Train Accuracy: 0.793333, Valid Accuracy: 0.812465, Loss: 0.568914
# Epoch 7500
# Train Accuracy: 0.786667, Valid Accuracy: 0.812845, Loss: 0.539606
# Epoch 7600
# Train Accuracy: 0.800000, Valid Accuracy: 0.812470, Loss: 0.555765
# Epoch 7700
# Train Accuracy: 0.793333, Valid Accuracy: 0.809925, Loss: 0.556890
# Epoch 7800
# Train Accuracy: 0.773333, Valid Accuracy: 0.813615, Loss: 0.531350
# Epoch 7900
# Train Accuracy: 0.793333, Valid Accuracy: 0.812890, Loss: 0.520122
# Epoch 8000
# Train Accuracy: 0.793333, Valid Accuracy: 0.813420, Loss: 0.549077
# Epoch 8100
# Train Accuracy: 0.786667, Valid Accuracy: 0.812100, Loss: 0.558652
# Epoch 8200
# Train Accuracy: 0.793333, Valid Accuracy: 0.812060, Loss: 0.518194
# Epoch 8300
# Train Accuracy: 0.780000, Valid Accuracy: 0.816075, Loss: 0.553847
# Epoch 8400
# Train Accuracy: 0.780000, Valid Accuracy: 0.813725, Loss: 0.488516
# Epoch 8500
# Train Accuracy: 0.780000, Valid Accuracy: 0.814725, Loss: 0.552294
# Epoch 8600
# Train Accuracy: 0.786667, Valid Accuracy: 0.814725, Loss: 0.527232
# Epoch 8700
# Train Accuracy: 0.780000, Valid Accuracy: 0.813855, Loss: 0.475924
# Epoch 8800
# Train Accuracy: 0.780000, Valid Accuracy: 0.813660, Loss: 0.460506
# Epoch 8900
# Train Accuracy: 0.780000, Valid Accuracy: 0.814255, Loss: 0.524500
# Epoch 9000
# Train Accuracy: 0.786667, Valid Accuracy: 0.816255, Loss: 0.519760
# Epoch 9100
# Train Accuracy: 0.773333, Valid Accuracy: 0.816310, Loss: 0.549443
# Epoch 9200
# Train Accuracy: 0.793333, Valid Accuracy: 0.813640, Loss: 0.480897
# Epoch 9300
# Train Accuracy: 0.786667, Valid Accuracy: 0.816755, Loss: 0.465206
# Epoch 9400
# Train Accuracy: 0.800000, Valid Accuracy: 0.815665, Loss: 0.559208
# Epoch 9500
# Train Accuracy: 0.793333, Valid Accuracy: 0.812910, Loss: 0.496549
# Epoch 9600
# Train Accuracy: 0.780000, Valid Accuracy: 0.814985, Loss: 0.528695
# Epoch 9700
# Train Accuracy: 0.793333, Valid Accuracy: 0.814290, Loss: 0.584432
# Epoch 9800
# Train Accuracy: 0.786667, Valid Accuracy: 0.815425, Loss: 0.504706
# Epoch 9900
# Train Accuracy: 0.793333, Valid Accuracy: 0.813140, Loss: 0.500047
# Epoch 10000
# Train Accuracy: 0.773333, Valid Accuracy: 0.817120, Loss: 0.540704
# Epoch 10100
# Train Accuracy: 0.780000, Valid Accuracy: 0.814935, Loss: 0.582948
# Epoch 10200
# Train Accuracy: 0.800000, Valid Accuracy: 0.814835, Loss: 0.503432
# Epoch 10300
# Train Accuracy: 0.780000, Valid Accuracy: 0.816130, Loss: 0.500640
# Epoch 10400
# Train Accuracy: 0.780000, Valid Accuracy: 0.815880, Loss: 0.503578
# Epoch 10500
# Train Accuracy: 0.793333, Valid Accuracy: 0.813490, Loss: 0.513108
# Epoch 10600
# Train Accuracy: 0.793333, Valid Accuracy: 0.812285, Loss: 0.509375
# Epoch 10700
# Train Accuracy: 0.780000, Valid Accuracy: 0.815785, Loss: 0.513387
# Epoch 10800
# Train Accuracy: 0.786667, Valid Accuracy: 0.816995, Loss: 0.513754
# Epoch 10900
# Train Accuracy: 0.766667, Valid Accuracy: 0.815815, Loss: 0.483085
# Epoch 11000
# Train Accuracy: 0.786667, Valid Accuracy: 0.813500, Loss: 0.466657
# Train Accuracy: 0.780000, Valid Accuracy: 0.815330, Loss: 0.518843
# Epoch 17100
# Train Accuracy: 0.780000, Valid Accuracy: 0.816220, Loss: 0.506455
# Epoch 17200
# Train Accuracy: 0.780000, Valid Accuracy: 0.816570, Loss: 0.559957
# Epoch 17300
# Train Accuracy: 0.786667, Valid Accuracy: 0.812035, Loss: 0.516226
# Epoch 17400
# Train Accuracy: 0.786667, Valid Accuracy: 0.816120, Loss: 0.523556
# Epoch 17500
# Train Accuracy: 0.780000, Valid Accuracy: 0.813975, Loss: 0.568668
# Epoch 17600
# Train Accuracy: 0.793333, Valid Accuracy: 0.816250, Loss: 0.541360
# Epoch 17700
# Train Accuracy: 0.793333, Valid Accuracy: 0.816265, Loss: 0.511887
# Epoch 17800
# Train Accuracy: 0.786667, Valid Accuracy: 0.811845, Loss: 0.517876
# Epoch 17900
# Train Accuracy: 0.766667, Valid Accuracy: 0.816375, Loss: 0.448718
# Epoch 18000
# Train Accuracy: 0.793333, Valid Accuracy: 0.815605, Loss: 0.541735
# Epoch 18100
# Train Accuracy: 0.793333, Valid Accuracy: 0.814215, Loss: 0.490272
# Epoch 18200
# Train Accuracy: 0.780000, Valid Accuracy: 0.816020, Loss: 0.574947
# Epoch 18300
# Train Accuracy: 0.786667, Valid Accuracy: 0.814345, Loss: 0.453992
# Epoch 18400
# Train Accuracy: 0.780000, Valid Accuracy: 0.813455, Loss: 0.519634
# Epoch 18500
# Train Accuracy: 0.786667, Valid Accuracy: 0.812810, Loss: 0.561599
# Epoch 18600
# Train Accuracy: 0.780000, Valid Accuracy: 0.815465, Loss: 0.520474
# Epoch 18700
# Train Accuracy: 0.780000, Valid Accuracy: 0.813595, Loss: 0.483195
# Epoch 18800
# Train Accuracy: 0.786667, Valid Accuracy: 0.812170, Loss: 0.462087
# Epoch 18900
# Train Accuracy: 0.780000, Valid Accuracy: 0.815575, Loss: 0.515323
# Epoch 19000
# Train Accuracy: 0.800000, Valid Accuracy: 0.815565, Loss: 0.528450
# Epoch 19100
# Train Accuracy: 0.793333, Valid Accuracy: 0.815760, Loss: 0.530258
# Epoch 19200
# Train Accuracy: 0.793333, Valid Accuracy: 0.813025, Loss: 0.570880
# Epoch 19300
# Train Accuracy: 0.780000, Valid Accuracy: 0.815100, Loss: 0.515267
# Epoch 19400
# Train Accuracy: 0.800000, Valid Accuracy: 0.813630, Loss: 0.485486
# Epoch 19500
# Train Accuracy: 0.786667, Valid Accuracy: 0.815970, Loss: 0.510887
# Epoch 19600
# Train Accuracy: 0.793333, Valid Accuracy: 0.814255, Loss: 0.467944
# Epoch 19700
# Train Accuracy: 0.780000, Valid Accuracy: 0.813915, Loss: 0.527265
# Epoch 19800
# Train Accuracy: 0.800000, Valid Accuracy: 0.813755, Loss: 0.568314
# Epoch 19900
# Train Accuracy: 0.773333, Valid Accuracy: 0.815370, Loss: 0.537398
